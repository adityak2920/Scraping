# %%
import tweepy
import csv
import json
import pandas as pd
import requests
from bs4 import BeautifulSoup as BS
import re
import time

# %% [markdown]
# First part of the program where the data will be extracted and will be saved in json file

# %%
#loading twitter API credentials from the file which was saved
with open('twitter_credentials.json') as cred_data:
    info = json.load(cred_data)
    consumer_key = info['CONSUMER_KEY']
    consumer_secret = info['CONSUMER_SECRET']
    access_key = info['ACCESS_KEY']
    access_secret = info['ACCESS_SECRET']

# %%
# initialization of a list to hold all Tweets
alltweets = []

# %%
# Authorization and initialization
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_key, access_secret)
api = tweepy.API(auth)

# %%
# We will get the tweets with multiple requests of 200 tweets each
new_tweets = api.user_timeline(screen_name="midasIIITD", count=200)
# Appending the json part of the data to list
for tweet in new_tweets:
    alltweets.append(tweet._json)

# %%
# save id of 1 less than the oldest tweet
oldest = alltweets[-1]["id"] - 1

# %%
# grabbing tweets till none are left
while len(new_tweets) > 0:  
    # all subsiquent requests use the max_id param to prevent duplicates
    new_tweets = api.user_timeline(screen_name = "midasIIITD",count=200, max_id=oldest)

    # save most recent tweets
    # Appending the json part of the data to list
    for tweet in new_tweets:
        alltweets.append(tweet._json)
    oldest = alltweets[-1]["id"] - 1

    print("...%s tweets downloaded so far" % (len(alltweets)))

print("Total tweets downloaded %s" % (len(alltweets)))
# Out:
# ...302 tweets downloaded so far
# ...302 tweets downloaded so far
# Total tweets downloaded 302

# %%
# Creating a new JSON file and dumping the value into it
file = open('tweet.json', 'w')
json.dump(alltweets, file,indent = 4)

# %% [markdown]
# Second part of the program to parse the json file and display the output in tabular form

# %%
col_names = ["text", "Date and time", "number of favorites/likes", "number of retweets"]

# %%
# function to get no. of retweets
def get_retweet(data):
    try:
        ans = data["retweeted_status"]["retweet_count"] 
    except KeyError:
        ans = data["retweet_count"] 
    return ans

# %%
# function to get no. of likes
def get_favorite(data):
    try:
        ans = data["retweeted_status"]["favorite_count"] 
    except KeyError:
        ans = data["favorite_count"] 
    return ans

# %%
# the json which I am getting from API doen't contain information about no. of images present in tweet
# I tried to get the no. of images from HTML of tweet url but the website is restricting to get so many
# requests at the same time. So, I haven't included no. of images column
def get_photos(data):
    url = data["entities"]["urls"][0]["expanded_url"]
    r = requests.get(url)
    soup = BS(r.text)
    x = str(soup.find("div", {"class":"AdaptiveMedia-container"}))
    ans = len(set(re.findall(r'(https?://[^\s]+)', x)))
    return ans

# %%
# dataframe to show in tabular format
df = pd.DataFrame(columns=col_names)

# %%
# loading the saved JSON file
f = open("tweet.json", "rb")
data = json.load(f)

# %%
for tw in data:
    text = re.sub(r"http\S+", "", tw["text"])
    dt = t["created_at"].split()
    date = dt[2]+'-'+dt[1]+'-'+dt[-1]+"|"+dt[3]
    favorite = get_favorite(tw)
    retweet = get_retweet(tw)
#     images = get_photos(tw)
    df.loc[len(df)] = [text, date, favorite, retweet]

# %%
df
# Out:
#                                                   text         Date and time  \
# 0    Congratulations @midasIIITD students Simra Sha...  25-Mar-2019|13:01:57
# 1    The last date for submitting a solution for th...  25-Mar-2019|13:01:57
# 2    RT @IIITDelhi: @IIITDelhi invites application ...  25-Mar-2019|13:01:57
# 280  @NUSComputing Congratulations Abdelhak and Pro...  25-Mar-2019|13:01:57
# 281  RT @goodfellow_ian: One of the most anticipate...  25-Mar-2019|13:01:57
# 282     @the_dhumketu Great to have you in @midasIIITD  25-Mar-2019|13:01:57
# 283  Congratulation @soujanyaporia for being appoin...  25-Mar-2019|13:01:57
# 284  @IIITDelhi @the_dhumketu Thanks team @midasIIITD   25-Mar-2019|13:01:57
# 285  RT @IIITDelhi: Congratulations @midasIIITD int...  25-Mar-2019|13:01:57
# 286  RT @learning_pt: Profile of the 5 Indian under...  25-Mar-2019|13:01:57
# 287  Have a look at the list of accepted papers in ...  25-Mar-2019|13:01:57
# 288  RT @goodfellow_ian:  TensorFuzz automates the ...  25-Mar-2019|13:01:57
# 289  RT @IIITDelhi: Congratulations Dr. @RatnRajiv ...  25-Mar-2019|13:01:57
# 290  RT @ylecun: Jitendra Malik, who directs FAIR-M...  25-Mar-2019|13:01:57
# 291  RT @kdnuggets: .@Bloomberg launches free cours...  25-Mar-2019|13:01:57
# 292  RT @TechAtBloomberg: Missed #PyLondinium18? Wa...  25-Mar-2019|13:01:57
# 293  RT @IIITDelhi: We are delighted to announce th...  25-Mar-2019|13:01:57
# 294  Get ready for the annual technical fest of @II...  25-Mar-2019|13:01:57
# 295  Congratulations Dr. @RatnRajiv and team @midas...  25-Mar-2019|13:01:57
# 296  Congratulations MIDAS @midasIIITD intern Prakh...  25-Mar-2019|13:01:57
# 297                           MIDAS@IIITD foundation.   25-Mar-2019|13:01:57
# 298      It feels great to be the part of @IIITDelhi.   25-Mar-2019|13:01:57
# 299  Thank you, @toonzratn for designing the logo o...  25-Mar-2019|13:01:57
# 300  We are on Facebook too. Like our page to get o...  25-Mar-2019|13:01:57
# 301  MIDAS is a group of researchers at IIIT-Delhi ...  25-Mar-2019|13:01:57
#
#     number of favorites/likes number of retweets
# 0                           8                  1
# 1                           8                  3
# 2                           4                  4
# 3                           4                  0
# 4                           6                  5
# 5                          13                  3
# 6                           1                  1
# 7                           6                  5
# 8                           6                  3
# 9                          15                  4
# 10                          7                  0
# 11                          1                  1
# 12                          7                  2
# 13                          7                  2
# 14                          6                  2
# 15                          1                  0
# 16                         14                 13
# 17                        236                 67
# 18                         16                  4
# 19                          0                  0
# 20                          4                  0
# 21                          3                  0
# 22                          1                  1
# 23                        141                 64
# 24                          1                  0
# 25                          8                  4
# 26                          3                  0
# 27                         45                 22
# 28                        127                 35
# 29                          1                  0
# ..                        ...                ...
# 272                       568                265
# 273                         2                  1
# 274                         3                  1
# 275                         6                  1
# 276                        88                 40
# 277                         1                  1
# 278                         1                  1
# 279                         1                  1
# 280                         0                  0
# 281                       424                103
# 282                         0                  0
# 283                         6                  1
# 284                         5                  1
# 285                         7                  4
# 286                         4                  4
# 287                         1                  0
# 288                       758                264
# 289                        14                  2
# 290                       218                 57
# 291                       225                105
# 292                         7                  7
# 293                        36                  6
# 294                         3                  2
# 295                         8                  2
# 296                         5                  1
# 297                         2                  1
# 298                         2                  1
# 299                         4                  1
# 300                         3                  1
# 301                         7                  4
#
# [302 rows x 4 columns]
